# %% [markdown]
# ### Baging
#
# Bagging, also known as Bootstrap Aggregating, is used to improve the accuracy and makes the model more generalize by reducing the variance i.e. by avoiding overfitting. In this, we take multiple subsets of the training dataset. For each subset, we take a model with the same learning algorithms like Decision tree, Logistic regression, etc. to predict the output for the same set of test data. Once we have a prediction from each model then we use a model averaging technique to get the final prediction output.
#
# Two of the most common Bagging models are (1) Bagged Decision Trees and (2) Random Forest.

# %% [markdown]
# #### Bagged Decision Trees
# A Decision Tree model takes X data and finds rules to split the data into separate datasets. When learning about Decision Trees, my General Assembly instructor, Matt Brems, compared running the model to a game of 20 Questions. Based on the data (question), your model will figure out what the best X variable to split on at each node.
# Compared to a regular decision tree, a bagged decision tree uses N # of trees and each tree is used on its own bootstrap sample. Predictions are based on the aggregate vote of the class.

# %% [markdown]
# #### Random Forest
#
# Random Forest is similar to bagged decision trees. Unlike bagged decision trees, Random Forests attempts to de-correlate trees from one another. Instead of choosing the best split point in the decision tree, the Random Forest model will only have a random subset of features considered for each split. In a Random Forest, the trees run parallel, and there is no interaction between the trees when they are building.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Advantages of Bagging
#     •	The biggest advantage of bagging is that multiple weak learners can work better than a single strong learner.
#     •	It provides stability and increases the accuracy of the machine learning algorithm that is used in statistical classification and regression.
#     •	It helps in reducing variance i.e. it avoids overfitting.
# #### Disadvantages of Bagging
#     •	It may result in high bias if it is not modeled properly and thus may result in underfitting.
#     •	Since we must use multiple models, it becomes computationally expensive and may not be suitable in various use cases.
