# %% [markdown]
#     1. True-False: Linear Regression is a supervised machine learning algorithm.

# %% [markdown]
#     2. Which of the following evaluation metrics can be used to evaluate a model while modeling a continuous output variable? -D
#         A) AUC-ROC
#         B) Accuracy
#         C) Logloss
#         D) Mean-Squared-Error

# %% [markdown]
#     1. Which of the following is NOT supervised learning?
#         A. PCA
#         B. Decision Tree
#         C. Linear Regression
#         D. Naive Bayesian

# %% [markdown]
#     2.Which of the following metrics is used for a categorical outcome?
#         A. RMSE
#         B. RSquared
#         C. Accuracy
#         D. All of the Mentioned

# %% [markdown]
#     3. The below figure shows AUC-ROC curves for three logistic regression models. Different colors show curves for different hyper parameters values. Which of the following AUC-ROC will give best result?
# ![image.png](attachment:image.png)
#
#         A. Yellow
#         B. Pink
#         C. Black
#         D. All are same

# %% [markdown]
#     4. Which of the following techniques can be used for normalization in text mining?
#         A. Stemming
#         B. Lemmatization
#         C. Stop Word Removal
#         D. Both A and B

# %% [markdown]
#     5.Which of the folllowing is an example of feature extraction?
#         A. Constructing bag of words vector from an email
#         B. Applying PCA projects to a large high-dimensional data
#         C. Removing stopwords in a sentence
#         D. All of the above
